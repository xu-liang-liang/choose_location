# %%
import joblib
from flask import Flask,request
import pandas as pd
app = Flask(__name__)

@app.route('/')
def hello_world():
    return 'Hello World!'

@app.route('/predict/<sen>')
def predict(sen):
    res = dict()
    # sen = list(sen)
    # sen = [int(i) for i in sen if i.isdigit()]
    sen = sen[1:-1].split(",")
    sen = [float(i) for i in sen]
    feature = ['dc_count', 'three_order_3km', 'total_order_3km', 'equipment_count', 'xj_order_3km', 'd_7day_total_order_count', 'd_7day_three_order_count', 'd_7day_tld_order_count', 'd_7day_xj_order_count', 'd_house_count', 'd_7day_xx_order_count', 'xx_order_3km', 'd_park_count', 'tld_order_3km', 'c_xp_total_count', 'd_shopping_count', 'd_populace_density', 'd_work_count', 'station_total_3km']
    for i in range(len(feature)):
        res[feature[i]] = sen[i]
    sen = pd.DataFrame(res, index=[0])
    # print(sen)
    result = model.predict(sen)
    # return result
    return str(result[0])

if __name__ == '__main__':
    model_path = "C:/UsersIdeaProjects/V3.0/loan_model_rf.pkl"
    model = joblib.load(model_path)
    app.run(host='*****')
    # app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://10.10.9.93:5000/ (Press CTRL+C to quit)
# 10.10.9.93 - - [17/Jun/2022 14:11:33] "GET /predict/[8,3499,3499,8,1735,6002,6002,2125,0,1735,1405,198,1322,419,569,201,1211,1036.0,100] HTTP/1.1" 200 -
