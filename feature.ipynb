# %%
import pandas as pd
from pyhive import hive
from matplotlib import pyplot as plt
host='*****'
username='*****'
password='*****'
port=10000
data_base_name='*****'
#连接hive
conn = hive.Connection(host=host,
                       port=port,
                       auth="CUSTOM",
                       database=data_base_name,
                       username=username,
                       password=password)

#读取数据
sql_order = 'select * from ***** where dt = "2022-06-12" or dt = "2022-06-19"'
train_data = pd.read_sql(sql_order, conn)
# conn.close
print(train_data.info())
# Out:
#              station_id             station_name  7_day_order_count city  \
# 0      1690751108474928         山东省日照市东港区后村公共快充站                 34  日照市
# 1       282572462057520            山东省日照市西站公共充电站                120  日照市
# 2      1128048405044944            晋江中骏四季花城迅源充电站                306  泉州市
# 3      1690363616651312   安徽省芜湖市鸠江区南翔万商B地块停车场充电站                 83  芜湖市
# 4      1689773953083440     沈海高速朴里服务区公共充电站（海口方向）                493  泉州市
# ...                 ...                      ...                ...  ...
# 63354   283028592917552               万马爱充南大科学园站                428  南京市
# 63355  1689414386683952            宁波市镇海山外山酒楼庄市店                  1  宁波市
# 63356   565107159572944  开迈斯充电站(宁波市九龙湖开元度假村交直流站)                  0  宁波市
# 63357   353171675966256         山西省太原市清徐县供电公司充电站                352  太原市
# 63358  1690181706004944          阳江市阳春陂面供电所公共充电站                  5  阳江市
#
#       city_code district district_code  position_type  operate_construction  \
# 0        371100      东港区        371102            NaN                   2.0
# 1        371100      东港区        371102            NaN                   6.0
# 2        350500      晋江市        350582            0.0                   1.0
# 3        340200      鸠江区        340207            NaN                   2.0
# 4        350500      晋江市        350582            NaN                  11.0
# ...         ...      ...           ...            ...                   ...
# 63354    320100      栖霞区        320113            NaN                 255.0
# 63355    330200      镇海区        330211            NaN                   7.0
# 63356    330200      镇海区        330211            0.0                 255.0
# 63357    140100      清徐县        140121            NaN                   2.0
# 63358    441700      阳春市        441781            NaN                   3.0
#
#        station_type  ...  wl_order_3km  xx_order_3km  tld_order_3km  \
# 0                 1  ...             0             0              0
# 1                 1  ...             0             0              0
# 2                 1  ...             0           247            924
# 3                 1  ...             0             0            419
# 4                 1  ...             0             0              0
# ...             ...  ...           ...           ...            ...
# 63354             1  ...             0             0              0
# 63355             1  ...             0           558            958
# 63356             1  ...             0             0              0
# 63357             1  ...             0             0              0
# 63358             1  ...             0             0              0
#
#       xj_order_3km equipment_count_3km dc_count_3km  d_total_equipment_count  \
# 0                0                   2            2                      353
# 1                0                  13           13                      351
# 2             3235                 163          149                     2100
# 3                0                 113           85                      367
# 4                0                  18           18                     2104
# ...            ...                 ...          ...                      ...
# 63354            0                 155          156                     1200
# 63355            0                 150          188                      363
# 63356            0                   0            0                      360
# 63357            0                  10           12                      141
# 63358            0                   3            3                       85
#
#        d_total_dc_count  average_fee          dt
# 0                   329         1.18  2022-06-12
# 1                   326         1.16  2022-06-12
# 2                  2163         0.89  2022-06-12
# 3                   235         1.16  2022-06-12
# 4                  2167         1.51  2022-06-12
# ...                 ...          ...         ...
# 63354              1274         1.15  2022-06-19
# 63355               410         1.12  2022-06-19
# 63356               412         1.60  2022-06-19
# 63357                42         0.76  2022-06-19
# 63358                64         1.16  2022-06-19
#
# [63359 rows x 73 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63359 entries, 0 to 63358
# Data columns (total 73 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   station_id                 63359 non-null  int64
#  1   station_name               63359 non-null  object
#  2   7_day_order_count          63359 non-null  int64
#  3   city                       63359 non-null  object
#  4   city_code                  63289 non-null  object
#  5   district                   63357 non-null  object
#  6   district_code              63359 non-null  object
#  7   position_type              10565 non-null  float64
#  8   operate_construction       63357 non-null  float64
#  9   station_type               63359 non-null  int64
#  10  equipment_count            63359 non-null  int64
#  11  ac_count                   63359 non-null  int64
#  12  dc_count                   63359 non-null  int64
#  13  power_count                62923 non-null  object
#  14  fee_info                   62309 non-null  object
#  15  payment                    0 non-null      object
#  16  d_house_count              63359 non-null  int64
#  17  d_work_count               63359 non-null  int64
#  18  d_shopping_count           63359 non-null  int64
#  19  d_traffic_count            63359 non-null  int64
#  20  d_scenic_count             63359 non-null  int64
#  21  d_populace                 63359 non-null  float64
#  22  d_area                     63359 non-null  float64
#  23  d_populace_density         63359 non-null  float64
#  24  c_total_invertory_count    63359 non-null  int64
#  25  c_2021_total_count         63359 non-null  int64
#  26  c_2021_down_year           63359 non-null  int64
#  27  c_tsl_total_count          63359 non-null  int64
#  28  c_wl_total_count           63359 non-null  int64
#  29  c_xp_total_count           63359 non-null  int64
#  30  d_total_station_count      63359 non-null  int64
#  31  d_tsl_station_count        63359 non-null  int64
#  32  d_wl_station_count         63359 non-null  int64
#  33  d_xp_station_count         63359 non-null  int64
#  34  d_xx_station_count         63359 non-null  int64
#  35  d_tld_station_count        63359 non-null  int64
#  36  d_kms_station_count        63359 non-null  int64
#  37  d_xj_station_count         63359 non-null  int64
#  38  d_7day_total_order_count   63359 non-null  int64
#  39  d_7day_haohan_order_count  63359 non-null  int64
#  40  d_7day_three_order_count   63359 non-null  int64
#  41  d_7day_wl_order_count      63359 non-null  int64
#  42  d_7day_xx_order_count      63359 non-null  int64
#  43  d_7day_tld_order_count     63359 non-null  int64
#  44  d_7day_xj_order_count      63359 non-null  int64
#  45  c_is_restrict              63359 non-null  bool
#  46  d_park_count               63359 non-null  int64
#  47  house_3km                  63359 non-null  int64
#  48  work_3km                   63359 non-null  int64
#  49  shopping_3km               63359 non-null  int64
#  50  traffic_3km                63359 non-null  int64
#  51  scenic_3km                 63359 non-null  int64
#  52  station_total_3km          63359 non-null  int64
#  53  tsl_3km                    63359 non-null  int64
#  54  wl_3km                     63359 non-null  int64
#  55  xp_3km                     63359 non-null  int64
#  56  xx_3km                     63359 non-null  int64
#  57  tld_3km                    63359 non-null  int64
#  58  kms_3km                    63359 non-null  int64
#  59  parking_3km                63359 non-null  int64
#  60  total_order_3km            63359 non-null  int64
#  61  haohan_order_3km           63359 non-null  int64
#  62  three_order_3km            63359 non-null  int64
#  63  wl_order_3km               63359 non-null  int64
#  64  xx_order_3km               63359 non-null  int64
#  65  tld_order_3km              63359 non-null  int64
#  66  xj_order_3km               63359 non-null  int64
#  67  equipment_count_3km        63359 non-null  int64
#  68  dc_count_3km               63359 non-null  int64
#  69  d_total_equipment_count    63359 non-null  int64
#  70  d_total_dc_count           63359 non-null  int64
#  71  average_fee                63359 non-null  float64
#  72  dt                         63359 non-null  object
# dtypes: bool(1), float64(6), int64(57), object(9)
# memory usage: 34.9+ MB
# None

# %%
train_data.rename(columns={"7_day_order_count":"week_day_order_count"},inplace=True)
train_data = train_data.drop(train_data[train_data.week_day_order_count == 0].index)

# %%
pd.set_option('display.max_rows', None)
train_data.isnull().sum()
# Out:
# station_id                       0
# station_name                     0
# week_day_order_count             0
# city                             0
# city_code                       54
# district                         2
# district_code                    0
# position_type                43145
# operate_construction             0
# station_type                     0
# equipment_count                  0
# ac_count                         0
# dc_count                         0
# power_count                     35
# fee_info                       694
# payment                      51608
# d_house_count                    0
# d_work_count                     0
# d_shopping_count                 0
# d_traffic_count                  0
# d_scenic_count                   0
# d_populace                       0
# d_area                           0
# d_populace_density               0
# c_total_invertory_count          0
# c_2021_total_count               0
# c_2021_down_year                 0
# c_tsl_total_count                0
# c_wl_total_count                 0
# c_xp_total_count                 0
# d_total_station_count            0
# d_tsl_station_count              0
# d_wl_station_count               0
# d_xp_station_count               0
# d_xx_station_count               0
# d_tld_station_count              0
# d_kms_station_count              0
# d_xj_station_count               0
# d_7day_total_order_count         0
# d_7day_haohan_order_count        0
# d_7day_three_order_count         0
# d_7day_wl_order_count            0
# d_7day_xx_order_count            0
# d_7day_tld_order_count           0
# d_7day_xj_order_count            0
# c_is_restrict                    0
# d_park_count                     0
# house_3km                        0
# work_3km                         0
# shopping_3km                     0
# traffic_3km                      0
# scenic_3km                       0
# station_total_3km                0
# tsl_3km                          0
# wl_3km                           0
# xp_3km                           0
# xx_3km                           0
# tld_3km                          0
# kms_3km                          0
# parking_3km                      0
# total_order_3km                  0
# haohan_order_3km                 0
# three_order_3km                  0
# wl_order_3km                     0
# xx_order_3km                     0
# tld_order_3km                    0
# xj_order_3km                     0
# equipment_count_3km              0
# dc_count_3km                     0
# d_total_equipment_count          0
# d_total_dc_count                 0
# average_fee                      0
# dt                               0
# dtype: int64

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, make_scorer, mean_squared_log_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
for vals in range(20, 0, -2):
    vals = vals/100
    # print(train_data.corr()["week_day_order_count"].sort_values(ascending = False))
    sort_feature = dict(train_data.corr()["week_day_order_count"].sort_values(ascending = False))
    imp_feature = [key for key, val in sort_feature.items() if val >= vals][1:]
    # print(imp_feature)
    #数据集打乱

    train_data = shuffle(train_data,random_state = 19)
    week_day_order_count = train_data.week_day_order_count
    x_train, x_test, y_train, y_test = train_test_split(train_data[imp_feature],week_day_order_count, test_size=0.2, random_state = 10)
    rf_model = RandomForestRegressor(n_estimators=320, random_state=0)
    rf_model.fit(x_train, y_train)
    rf_pred = rf_model.predict(x_test)
    print(vals, mean_squared_error(y_test, rf_pred) ** 0.5)
# Out:
# 0.2 283.4008028089081
# 0.18 258.918730704718
# 0.16 226.75736148009761
# 0.14 240.12567319003378
# 0.12 206.87108242307914
# 0.1 294.85255402637546
# 0.08 231.93583114975863
# 0.06 227.8423605311907
